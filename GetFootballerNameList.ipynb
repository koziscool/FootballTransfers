# %%
import numpy as np
import pandas as pd

# %%
footballers = pd.read_csv("GuardianList.csv", usecols = [10, 12], skiprows=3)
print(footballers.head())
all_footballers_dict = dict(zip(footballers['Name'], footballers['Club at Dec 20 2020']))
print(len(all_footballers_dict))
all_footballers_dict
# Out:
#                  Name Club at Dec 20 2020
# 0  Robert Lewandowski       Bayern Munich
# 1        Lionel Messi           Barcelona
# 2   Cristiano Ronaldo            Juventus
# 3     Kevin De Bruyne     Manchester City
# 4          Sadio Mané           Liverpool
# 440
# {'Robert Lewandowski': 'Bayern Munich',
#  'Lionel Messi': 'Barcelona',
#  'Cristiano Ronaldo': 'Juventus',
#  'Kevin De Bruyne': 'Manchester City',
#  'Sadio Mané': 'Liverpool',
#  'Erling Braut Haaland': 'Borussia Dortmund',
#  'Kylian Mbappé': 'Paris St-Germain',
#  'Mohamed Salah': 'Liverpool',
#  'Neymar': 'Paris St-Germain',
#  'Virgil van Dijk': 'Liverpool',
#  'Joshua Kimmich': 'Bayern Munich',
#  'Karim Benzema': 'Real Madrid',
#  'Sergio Ramos': 'Real Madrid',
#  'Thomas Müller': 'Bayern Munich',
#  'Manuel Neuer': 'Bayern Munich',
#  'Serge Gnabry': 'Bayern Munich',
#  'Thiago Alcântara': 'Liverpool',
#  'Trent Alexander-Arnold': 'Liverpool',
#  'Romelu Lukaku': 'Inter',
# ...
