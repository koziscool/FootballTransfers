# %%
import numpy as np
import pandas as pd

# %%
# footballers = pd.read_csv("GuardianList.csv", usecols = [9, 10, 11, 12, 13], skiprows=1)
footballers = pd.read_csv("GuardianList.csv", usecols = [10], skiprows=3)
# footballers.columns
footballers_names = list(footballers['Name'])
# print(footballers)
print(len(footballers_names))
footballers_names
# Out:
# 441
# ['Robert Lewandowski',
#  'Lionel Messi',
#  'Cristiano Ronaldo',
#  'Kevin De Bruyne',
#  'Sadio Mané',
#  'Erling Braut Haaland',
#  'Kylian Mbappé',
#  'Mohamed Salah',
#  'Neymar',
#  'Virgil van Dijk',
#  'Joshua Kimmich',
#  'Karim Benzema',
#  'Sergio Ramos',
#  'Thomas Müller',
#  'Manuel Neuer',
#  'Serge Gnabry',
#  'Thiago Alcântara',
#  'Trent Alexander-Arnold',
#  'Romelu Lukaku',
#  'Harry Kane',
#  'Bruno Fernandes',
#  'Son Heung-min',
#  'Alphonso Davies',
#  'Ciro Immobile',
#  'Zlatan Ibrahimovic',
#  'Alisson',
#  'Raheem Sterling',
#  'Jan Oblak',
#  'Jadon Sancho',
#  'Timo Werner',
#  'David Alaba',
#  'Alejandro ‘Papu’ Gomez',
#  'Jordan Henderson',
#  'Andrew Robertson',
#  'Jamie Vardy',
#  'Pierre-Emerick Aubameyang',
#  'João Félix',
#  'Angel Di María',
#  'Paulo Dybala',
#  'Leon Goretzka',
#  'Marcus Rashford',
#  'Toni Kroos',
#  'Roberto Firmino',
#  'Lautaro Martínez ',
#  'Ansu Fati',
#  'Thibaut Courtois',
#  'Kingsley Coman',
# ...
